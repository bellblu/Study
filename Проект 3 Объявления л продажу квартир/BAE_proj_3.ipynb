# %% [markdown]
# #### Андрей, привет!
#
# Меня зовут Максим Попов, и я буду проверять твой проект. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом.
# По ходу тетрадки ты найдешь комментарии к проекту, они будут в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Постарайся учесть эти комментарии для дальнейших проектов.
#
# ---
#
# Я буду отмечать комментарии цветом и примечанием. В конце заголовка комментария будет указан номер итерации проверки. Пожалуйста, не удаляй и не правь мои комментарии
#
# Критично - требует исправления, влияет на удачное выполнение проекта
#
# Рекомендация - комментарий является рекомендацией или советом. Mожешь учесть их при выполнении будущих заданий. На твое усмотрение
#
# Отлично - Так отмечены удачные решения и подходы, на которые стоит опираться в будущих проектах
#
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера
# Критично
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера
# Рекомендация
#
# Такой комментарий является рекомендацией или советом. Mожешь учесть их при выполнении будущих заданий. На твое усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера
# Отлично
#
# Так отмечены удачные решения и подходы, на которые стоит опираться в будущих проектах
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# У тебя отличная работа, но некоторые моменты надо исправить, они отмечены красными комментариями с пометкой критично. Рекомендую взглянуть на проект до и после исправлений.
#
# Желтые комментарии-рекомендации на твое усмотрение.
#
# Если есть вопросы ко мне, можешь оставить их в отдельном комментарии
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_2
#
# Андрей, привет!
#
# Все критичные замечания отработаны, отлично!
#
# Изини, что запутал тебя с боксплотами, ты прав, ограничения по оси не влияют на расчеты выбросов.
#
# </div>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Андрей,-привет!" data-toc-modified-id="Андрей,-привет!-0.0.0.1">Андрей, привет!</a></span></li></ul></li><li><span><a href="#Комментарий-от-ревьюера" data-toc-modified-id="Комментарий-от-ревьюера-0.0.1">Комментарий от ревьюера</a></span></li><li><span><a href="#Комментарий-от-ревьюера" data-toc-modified-id="Комментарий-от-ревьюера-0.0.2">Комментарий от ревьюера</a></span></li><li><span><a href="#Комментарий-от-ревьюера" data-toc-modified-id="Комментарий-от-ревьюера-0.0.3">Комментарий от ревьюера</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-0.0.4">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_2" data-toc-modified-id="Комментарий-от-ревьюера-v_2-0.0.5">Комментарий от ревьюера v_2</a></span></li></ul></li></ul></li><li><span><a href="#Исследование-объявлений-о-продаже-квартир" data-toc-modified-id="Исследование-объявлений-о-продаже-квартир-1">Исследование объявлений о продаже квартир</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.0.1">Комментарий от ревьюера v_1</a></span></li></ul></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1.1">Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.1.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.1.2">Комментарий студента</a></span></li><li><span><a href="#Ознакомившись-с-данными:" data-toc-modified-id="Ознакомившись-с-данными:-1.1.3">Ознакомившись с данными:</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.1.4">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.1.5">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.1.6">Комментарий студента</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.1.7">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.1.8">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.1.9">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.1.10">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1.11">Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.2">Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.2.2">Комментарий студента</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.3">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.2.4">Комментарий студента</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.5">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.2.6">Комментарий студента</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.7">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.8">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.9">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.10">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.2.11">Вывод</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.12">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.2.13">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.2.14">Комментарий студента</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-1.3">Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.2">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.3">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.4">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера" data-toc-modified-id="Комментарий-от-ревьюера-1.3.5">Комментарий от ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.3.6">Комментарий студента</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.7">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.8">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.3.9">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.3.10">Комментарий студента</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.3.11">Вывод</a></span></li><li><span><a href="#Комментарий-от-ревьюера" data-toc-modified-id="Комментарий-от-ревьюера-1.3.12">Комментарий от ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.3.13">Комментарий студента</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-1.4">Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Анализ-всех-данных" data-toc-modified-id="Анализ-всех-данных-1.4.2">Анализ всех данных</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.3">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4.4">Комментарий студента</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_2" data-toc-modified-id="Комментарий-от-ревьюера-v_2-1.4.5">Комментарий от ревьюера v_2</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4.6">Комментарий студента</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.7">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.8">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.9">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.10">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4.11">Комментарий студента</a></span></li><li><span><a href="#Анализ-данных-закрытых-объявлений" data-toc-modified-id="Анализ-данных-закрытых-объявлений-1.4.12">Анализ данных закрытых объявлений</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.13">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.14">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.15">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4.16">Комментарий студента</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.17">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4.18">Комментарий студента</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.4.18.1">Вывод</a></span></li></ul></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.19">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Топ-по-населеным-пунктам" data-toc-modified-id="Топ-по-населеным-пунктам-1.4.20">Топ по населеным пунктам</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.4.20.1">Вывод</a></span></li></ul></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.21">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4.22">Комментарий студента</a></span></li><li><span><a href="#Анализ-данных-по-Санкт-Петербургу" data-toc-modified-id="Анализ-данных-по-Санкт-Петербургу-1.4.23">Анализ данных по Санкт-Петербургу</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.24">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4.25">Комментарий студента</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.4.25.1">Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных-по-квартирам-в-центре-Санкт-Петербурга" data-toc-modified-id="Анализ-данных-по-квартирам-в-центре-Санкт-Петербурга-1.4.26">Анализ данных по квартирам в центре Санкт-Петербурга</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.27">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4.28">Комментарий студента</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.29">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4.30">Комментарий студента</a></span></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.31">Комментарий от ревьюера v_1</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.4.31.1">Вывод</a></span></li></ul></li><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.4.32">Комментарий от ревьюера v_1</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-1.5">Общий вывод</a></span><ul class="toc-item"><li><span><a href="#Комментарий-от-ревьюера-v_1" data-toc-modified-id="Комментарий-от-ревьюера-v_1-1.5.1">Комментарий от ревьюера v_1</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.5.2">Комментарий студента</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-1.6">Чек-лист готовности проекта</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Молодец, что в начале проекта знакомишь с ним, так работа приобретает структуру и лучше воспринимается.
# </div>

# %% [markdown]
# ## Изучение данных из файла

# %%
pd.set_option('display.max_columns', 500)
pd.options.display.float_format = '{:.2f}'.format
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20 13000000.00      108.00  2019-03-07T00:00:00      3
# 1             7  3350000.00       40.40  2018-12-04T00:00:00      1
# 2            10  5196000.00       56.00  2015-08-20T00:00:00      2
# 3             0 64900000.00      159.00  2015-07-24T00:00:00      3
# 4             2 10000000.00      100.00  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70         16.00        51.00      8          NaN   False
# 1             nan         11.00        18.60      1          NaN   False
# 2             nan          5.00        34.30      4          NaN   False
# 3             nan         14.00          nan      9          NaN   False
# 4            3.03         14.00        32.00     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# Библиотеки следует импортировать в начале тетрадки, в отдельной ячейке
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Переместил импорт библиотек в самое начало.
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Ознакомившись с данными:
# 1. В данных нет явных дубликатов.
# 2. Большое количество пропущенных данных в ceiling_height, необходимо изучить их, возможно соспоставить пропущенные данные и среднюю высоту потолков в зависимости от количества этажей в здании или от расположения (в центре потолки выше).
# 3. Есть пропущенные значения во floors_total
# 4. Есть пропущенные значения в living_area и kitchen_area, изучим есть ли между ними зависимость и посмотрим что можно с этим сделать, возможно это европланировка где объединенная кухня и гостинная или спальня (если студия).
# 5. Пропущены значения в is_apartment, скорей всего пропуск означает "Нет"
# 5. Есть пропуски в balcony, скорей всего связаны с их отсутствием
# 6. Есть пропуски в locality_name, надо узнать с чем они связаны и посмотреть возможно ли востановить данные по растоянию от центра
# 7. Пропуски в данных airports_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, скорей всего связаны с их отсутствием.
# 8. Пропуск в days_exposition вероятней обозначает что объявление еще размещено.
# 9. last_price, floors_total, balcony, airports_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition заменить на тип данных int64,

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Молодец, что после применения info обращаешь внимание на возможные несоответсвия и пишешь дальнейший план действий. Так ты ничего не упустишь и глубже посмотришь на данныея.
# </div>

# %%
data['ceiling_height'].sort_values().unique()
# Out:
# array([  1.  ,   1.2 ,   1.75,   2.  ,   2.2 ,   2.25,   2.3 ,   2.34,
#          2.4 ,   2.45,   2.46,   2.47,   2.48,   2.49,   2.5 ,   2.51,
#          2.52,   2.53,   2.54,   2.55,   2.56,   2.57,   2.58,   2.59,
#          2.6 ,   2.61,   2.62,   2.63,   2.64,   2.65,   2.66,   2.67,
#          2.68,   2.69,   2.7 ,   2.71,   2.72,   2.73,   2.74,   2.75,
#          2.76,   2.77,   2.78,   2.79,   2.8 ,   2.81,   2.82,   2.83,
#          2.84,   2.85,   2.86,   2.87,   2.88,   2.89,   2.9 ,   2.91,
#          2.92,   2.93,   2.94,   2.95,   2.96,   2.97,   2.98,   2.99,
#          3.  ,   3.01,   3.02,   3.03,   3.04,   3.05,   3.06,   3.07,
#          3.08,   3.09,   3.1 ,   3.11,   3.12,   3.13,   3.14,   3.15,
#          3.16,   3.17,   3.18,   3.2 ,   3.21,   3.22,   3.23,   3.24,
#          3.25,   3.26,   3.27,   3.28,   3.29,   3.3 ,   3.31,   3.32,
#          3.33,   3.34,   3.35,   3.36,   3.37,   3.38,   3.39,   3.4 ,
# ...

# %%
data['ceiling_height'].value_counts().head(20)
# Out:
# 2.50    3515
# 2.60    1646
# 2.70    1574
# 3.00    1112
# 2.80     993
# 2.55     980
# 2.75     910
# 2.65     676
# 3.20     277
# 3.10     203
# 2.90     164
# 3.30     141
# 2.56     139
# 3.50     130
# 2.57     103
# 2.85     101
# 3.40      92
# 2.54      83
# 2.64      81
# 2.52      79
# Name: ceiling_height, dtype: int64

# %%
data['ceiling_height'].describe()
# Out:
# count   14504.00
# mean        2.77
# std         1.26
# min         1.00
# 25%         2.52
# 50%         2.65
# 75%         2.80
# max       100.00
# Name: ceiling_height, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# Перед выводом лучше отсортировать
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Применил сортировку перед выводом уникальных значений, убрал гистограммы, думаю выведенной сверху информации достаточно для ознакомления
# </div>

# %% [markdown]
# **Имеются очень высокие значения такие как 14,24,25,100, скорей всего неправильный ввод данных. Замену буду проводить позже, по медианной**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Отличное исследование и правльный вывод
# </div>

# %%
data[data['floors_total'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 186              12 11640000.00       65.20  2018-10-02T00:00:00      2
# 237               4  2438033.00       28.10  2016-11-23T00:00:00      1
# 457               4  9788348.00       70.80  2015-08-01T00:00:00      2
# 671               4  6051191.00       93.60  2017-04-06T00:00:00      3
# 1757              5  3600000.00       39.00  2017-04-22T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 22542             5  8500000.00       63.50  2017-05-24T00:00:00      2
# 22656             4  4574160.00       64.50  2017-04-02T00:00:00      2
# 22808             0 14569263.00      110.40  2016-11-20T00:00:00      3
# 23590             0 21187872.00      123.30  2017-04-25T00:00:00      3
# 23658             6  3063600.00       43.80  2016-11-28T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
data[data['floors_total'].isna()]['floor'].unique()
# Out:
# array([ 4,  1, 12,  8,  9, 22, 15,  6,  7,  3, 18, 13, 24, 21, 11,  2,  5,
#        19, 20, 14, 17, 23, 10])

# %%
data['floors_total'].unique()
# Out:
# array([16., 11.,  5., 14., 12., 26., 24., 27.,  9.,  6., 17., 25.,  3.,
#        23., 19., 18.,  4., 22.,  8.,  2., 10.,  7., 13., 15., nan, 20.,
#        28., 36., 21., 35., 34., 60.,  1., 29., 33., 52., 37.])

# %%
n = 0
for floor in data[data['floors_total'].isna()]['floor'].unique():
    if floor in data['floors_total'].unique():
        n += 1
        #print(floor)
        
print('Уникальных значений floor в данных с пропущенным floors_total:   ', len(
    data[data['floors_total'].isna()]['floor'].unique())
     )
print('Уникальных значений входит в список уникальных значений floors_total:   ', n)
# Out:
# Уникальных значений floor в данных с пропущенным floors_total:    23
# Уникальных значений входит в список уникальных значений floors_total:    23

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# Для более удобной записи принта можешь использовать f-строки, ознакомиться с ними можешь по ссылке. После того, как один раз используешь к классической записи уже не вернешься)
#
# https://www.youtube.com/watch?v=QlkQNWQUCLc&list=PLQAt0m1f9OHvv2wxPGSCWjgy1qER_FvB6&index=14
# </div>

# %%
data.groupby(by='floors_total')['last_price'].count()
# Out:
# floors_total
# 1.00       25
# 2.00      383
# 3.00      668
# 4.00     1200
# 5.00     5788
# 6.00      914
# 7.00      592
# 8.00      390
# 9.00     3761
# 10.00    1174
# 11.00     203
# 12.00    1362
# 13.00     229
# 14.00     553
# 15.00     365
# 16.00    1376
# 17.00     833
# 18.00     505
# 19.00     339
# 20.00     271
# 21.00     158
# 22.00     286
# 23.00     352
# 24.00     469
# 25.00    1075
# 26.00     124
# 27.00     164
# 28.00      21
# 29.00       1
# 33.00       1
# 34.00       1
# 35.00      24
# 36.00       3
# 37.00       1
# 52.00       1
# 60.00       1
# Name: last_price, dtype: int64

# %%
len(data.query('floors_total == floor'))/len(data['floor'])
# Out:
# 0.14182032997172878

# %% [markdown]
# **Все значения floor в данных с пропущенным floors_total входят в список уникальных значений floors_total. Так как есть здания выше данных значений, однозначно сказать что квартира находится на последнем этаже нельзя. В данных всего 14% квартир находящихся на последнем этаже, поэтому при предобработке данных, заменим пропущенное значение во floors_total значением floor +1**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
# 👍🏻
#
# </div>

# %%
data[data['kitchen_area'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3                 0 64900000.00      159.00  2015-07-24T00:00:00      3
# 30               12  2200000.00       32.80  2018-02-19T00:00:00      1
# 37               10  1990000.00       45.80  2017-10-28T00:00:00      2
# 44               13  5350000.00       40.00  2018-11-18T00:00:00      1
# 59               15  6300000.00       46.50  2017-03-06T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23655             1  2414306.00       40.50  2016-09-08T00:00:00      1
# 23663            12  6400000.00       88.00  2018-01-12T00:00:00      4
# 23670             9  2450000.00       45.60  2018-02-08T00:00:00      1
# 23679             0  2500000.00       35.00  2017-12-08T00:00:00      1
# 23696            18  2500000.00       56.70  2018-02-11T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %% [markdown]
# **В данных пристутсвуют пропущенные значения living_area. Определим сколько значений где living_area заполнено.**

# %%
data[(data['kitchen_area'].isna()) & (~data['living_area'].isna())]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 144               1  2450000.00       27.00  2017-03-30T00:00:00      0
# 155               8 96000000.00      317.00  2017-07-07T00:00:00      4
# 178              18 16300000.00      153.00  2019-03-30T00:00:00      4
# 188              15  4600000.00       38.50  2019-04-16T00:00:00      1
# 199               4  3735325.00       37.40  2019-03-22T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23592            10  1450000.00       29.00  2017-11-11T00:00:00      0
# 23604             7  4300000.00       44.30  2019-04-13T00:00:00      2
# 23637             8  2350000.00       26.00  2018-06-26T00:00:00      0
# 23655             1  2414306.00       40.50  2016-09-08T00:00:00      1
# 23696            18  2500000.00       56.70  2018-02-11T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %% [markdown]
# Осталось 814 значений, однако в них нет зависимости.
#
# **Будем заполнять данные по kitchen_area в зависимости от данных в studio, если квартира студия, то площадь кухни = 0, в остальных случаях ориентироваться будем на медианные значения в зависимости от количества комнат или количества этажей в здании, или оставляем значения пропущенными.**

# %%
data[data['living_area'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3                 0 64900000.00      159.00  2015-07-24T00:00:00      3
# 7                 5  7915000.00       71.60  2019-04-18T00:00:00      2
# 30               12  2200000.00       32.80  2018-02-19T00:00:00      1
# 37               10  1990000.00       45.80  2017-10-28T00:00:00      2
# 44               13  5350000.00       40.00  2018-11-18T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23642            14  5950000.00       80.30  2018-07-03T00:00:00      3
# 23663            12  6400000.00       88.00  2018-01-12T00:00:00      4
# 23670             9  2450000.00       45.60  2018-02-08T00:00:00      1
# 23679             0  2500000.00       35.00  2017-12-08T00:00:00      1
# 23697            13 11475000.00       76.75  2017-03-28T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %% [markdown]
# **Заполнить данные невозможно, оставляем пропущенное либо смотрим на медианные значения по количеству комнат.**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
# Отлично
#
# И тут все верно 👍🏻
#
# </div>

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# **Видно наличие неявных дубликатов в locality_name**

# %%
data['locality_name'].value_counts().head(50)
# Out:
# Санкт-Петербург                            15721
# посёлок Мурино                               522
# посёлок Шушары                               440
# Всеволожск                                   398
# Пушкин                                       369
# Колпино                                      338
# посёлок Парголово                            327
# Гатчина                                      307
# деревня Кудрово                              299
# Выборг                                       237
# Петергоф                                     201
# Сестрорецк                                   183
# Красное Село                                 178
# Кудрово                                      173
# деревня Новое Девяткино                      144
# Сертолово                                    142
# Ломоносов                                    133
# Кириши                                       125
# Сланцы                                       112
# ...

# %%
data[data['locality_name'].isna()].head()
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 1097             3  8600000.00       81.70  2016-04-15T00:00:00      3
# 2033             6  5398000.00       80.00  2017-05-30T00:00:00      3
# 2603            20  3351765.00       42.70  2015-09-20T00:00:00      1
# 2632             2  5130593.00       62.40  2015-10-11T00:00:00      2
# 3574            10  4200000.00       46.50  2016-05-28T00:00:00      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 1097            3.55          5.00        50.80      2          NaN   False
# 2033             nan          4.00        42.60      2          NaN   False
# 2603             nan         24.00        15.60      3          NaN   False
# 2632             nan         24.00        33.10     21          NaN   False
# 3574             nan          5.00        30.80      5          NaN   False
#
#       open_plan  kitchen_area  balcony locality_name  airports_nearest  \
# ...

# %% [markdown]
# Определить locality_name можно только для Санкт-Петербурга, в зависимости от дальности от центра. Все равно изначально надо оценить зависимость растояния от центра и Населеных пунктов.

# %%
data[data['ponds_around3000'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5                10  2890000.00       30.40  2018-09-10T00:00:00      1
# 8                20  2900000.00       33.16  2018-05-23T00:00:00      1
# 12               10  3890000.00       54.00  2016-06-30T00:00:00      2
# 22               20  5000000.00       58.00  2017-04-24T00:00:00      2
# 30               12  2200000.00       32.80  2018-02-19T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23683            16  2100000.00       62.80  2018-09-18T00:00:00      4
# 23692             2  1350000.00       30.00  2017-07-07T00:00:00      1
# 23695            14  3100000.00       59.00  2018-01-15T00:00:00      3
# 23696            18  2500000.00       56.70  2018-02-11T00:00:00      2
# 23698             4  1350000.00       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
data[data['ponds_around3000'].isna()]['parks_nearest'].isna()
# Out:
# 5        True
# 8        True
# 12       True
# 22       True
# 30       True
#          ...
# 23683    True
# 23692    True
# 23695    True
# 23696    True
# 23698    True
# Name: parks_nearest, Length: 5518, dtype: bool

# %% [markdown]
# **Посмотрев Тихвин на карте мной было обноруженно что он находится рядом водоемами, однако в данных выше видно что заполненно пропусками, сделаю проверку по данному местоположению.**

# %%
data.query('locality_name == "Тихвин"')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 584              15  2550000.00       54.00  2018-02-07T00:00:00      3
# 1054              7  2500000.00       67.00  2018-10-28T00:00:00      3
# 1338              1  2400000.00       69.00  2018-03-16T00:00:00      3
# 1869             11  1830000.00       48.00  2016-04-06T00:00:00      2
# 3805              8  3600000.00       80.00  2018-11-08T00:00:00      2
# 4287             10  3590000.00       83.70  2017-09-13T00:00:00      3
# 4733             20  2150000.00       52.40  2017-11-09T00:00:00      2
# 4924             12  1600000.00       35.00  2018-02-05T00:00:00      1
# 6013              4  1860000.00       48.00  2017-08-20T00:00:00      2
# 6084              6   770000.00       18.00  2017-10-16T00:00:00      1
# 6758             13  1950000.00       44.60  2018-06-14T00:00:00      2
# 7690              2  1670000.00       48.00  2016-06-24T00:00:00      2
# ...

# %% [markdown]
# Проверка показала все данные касаемо аэропорта, центра, парков и водоемов в Тихвине пропущены.
#
# **По таким результатм я могу заменять пропуски в parks_nearest и ponds_nearest только при условии что parks_around3000 = 0 и ponds_around3000 = 0 соответственно.**

# %% [markdown]
# ### Вывод
# 1. Заменяем пропущенные floors_total на floor +1
# 2. ceiling_height заменяем на медианные в зависимости от количества этажей в здании.
# 3. living_area оставляем пропущенной
# 4. kitchen_area заменяем на 0 в случе studio = True, остальное оставляем пропущенным
# 5. last_price, floors_total, balcony, airports_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition заменить на тип данных int64, is_apartment на bool, first_day_exposition в формат datetime64
# 6. Избавиться от неявных дубликатов в locality_name
# 7. Заменить пропуски в balcony на 0
# 8. Заменить название столбца cityCenters_nearest

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# В начале шага следует написать перечень действий, который планируешь выполнить. Так ты
# ничего не упустишь и добавишь проекту структуры
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Учту данную рекомендацию в следующих проектах
# </div>

# %%
data.loc[data['floors_total'].isna(), 'floors_total'] = data[data['floors_total'].isna()]['floor'] + 1

# %% [markdown]
# **Заменили пропуски в floors_total**

# %%
#data.loc[data['ceiling_height'].isna(), 'ceiling_height'] = data['ceiling_height'].median()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# А почему закомментировано?
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Коментировал с целью обработки выбросов, чтоб не потерять лишние, применил замену позже.
# </div>

# %% [markdown]
# **Заменил пропущенные значения высоты потолков на медианные, т.к. скорей всего пропуск означал стандартную высоту потолков.**

# %%
data.loc[data['studio'] == True,'kitchen_area'] = 0

# %% [markdown]
# **Заменили пропуски в kitchen_area на 0 в квартирах студиях.**

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# **Заменили пропуски в balcony на 0**

# %%
data['days_exposition'].abs().min()
# Out:
# 1.0

# %%
data['days_exposition'] = data['days_exposition'].fillna(0)

# %% [markdown]
# **Так как пропуски в days_exposition обозначают что объявление еще не закрыто, заменим пропуски значением 0**

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# Такая замена допускается, но перед этим надо проверить данные, может быть там есть значения 0
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Добавил проверку
# </div>

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %%
data['last_price'] = data['last_price'].astype('int')
data['floors_total'] = data['floors_total'].astype(np.int)
#data['airports_nearest'] = data['airports_nearest'].astype('int')
#data['parks_around3000'] = data['parks_around3000'].astype('int')
#data['parks_nearest'] = data['parks_nearest'].astype('int')
#data['ponds_around3000'] = data['ponds_around3000'].astype('int')
#data['ponds_nearest'] = data['ponds_nearest'].astype('int')
data['days_exposition'] = data['days_exposition'].astype('int')
data['is_apartment'] = data['is_apartment'].astype('bool')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null int64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23699 non-null int64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21570 non-null float64
# balcony                 23699 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %%
data = data.rename(columns={'cityCenters_nearest':'city_centers_nearest'})

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# 👍🏻
#
# </div>

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00  2019-03-07T00:00:00      3
# 1             7     3350000       40.40  2018-12-04T00:00:00      1
# 2            10     5196000       56.00  2015-08-20T00:00:00      2
# 3             0    64900000      159.00  2015-07-24T00:00:00      3
# 4             2    10000000      100.00  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16        51.00      8         False   False
# 1             nan            11        18.60      1         False   False
# 2             nan             5        34.30      4         False   False
# 3             nan            14          nan      9         False   False
# 4            3.03            14        32.00     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Преобразование верно, но нам нужен именно день размещения объявления, время лучше отбросить
#
# </div>

# %% [markdown]
# **Перевел данные first_day_exposition в формат datetime64**

# %%
data.query('locality_name == "Санкт-Петербург"')['city_centers_nearest'].describe()
# Out:
# count   15660.00
# mean    11601.29
# std      4842.04
# min       181.00
# 25%      8327.00
# 50%     12244.50
# 75%     14943.00
# max     29493.00
# Name: city_centers_nearest, dtype: float64

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
for local in data[data['locality_name'].notna()]['locality_name'].unique():
    if 'Мурино' in local:
        data.loc[data['locality_name'] == local, 'locality_name'] = 'Мурино'
    elif 'Кудрово' in local:
        data.loc[data['locality_name'] == local, 'locality_name'] = 'Кудрово'
    elif 'Бугры' in local:
        data.loc[data['locality_name'] == local, 'locality_name'] = 'Бугры'

# %%
data['locality_name'].value_counts().head(50)
# Out:
# Санкт-Петербург                            15721
# Мурино                                       590
# Кудрово                                      472
# посёлок Шушары                               440
# Всеволожск                                   398
# Пушкин                                       369
# Колпино                                      338
# посёлок Парголово                            327
# Гатчина                                      307
# Выборг                                       237
# Петергоф                                     201
# Сестрорецк                                   183
# Красное Село                                 178
# деревня Новое Девяткино                      144
# Сертолово                                    142
# Ломоносов                                    133
# Кириши                                       125
# Бугры                                        114
# Сланцы                                       112
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Молодец, что попробовал обработать локации!
#
# </div>

# %% [markdown]
# **Заменил обнаруженные дубликаты Мурино, Кудрово, Бугры.** (Пробовал реализовать через Лематизацию, получилось каряво, решил вручную.)

# %%
data.loc[:,'living_area'] = data.groupby('rooms')\
.transform(lambda group : group.fillna(group.median()))['living_area']
data.loc[:,'kitchen_area'] = data.groupby('floors_total')\
.transform(lambda group : group.fillna(group.median()))['kitchen_area']
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
data[data['kitchen_area'].isna()]
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 1697            11     3550000       28.00           2018-02-08      1
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 1697            2.65            34        18.00     23         False   False
#
#       open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 1697      False           nan     0.00  Санкт-Петербург          18732.00
#
#       city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 1697              20444.00              0.00            nan              3.00
#
#       ponds_nearest  days_exposition
# 1697          80.00              410

# %%
data.loc[:,'kitchen_area'] = data.groupby('rooms')\
.transform(lambda group : group.fillna(group.median()))['kitchen_area']

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Отличный код 👍🏻
#
# </div>

# %% [markdown]
# **Заменил пропущенные данные в living_area на медианные в зависимости от количества комнат, а kitchen_area на медианные в зависимости от количества этажей в доме, так как в большинстве случаев планировка зависит от этажности здания. После замены осталось одно пропущенное значение в  kitchen_area, заменил его на медианное в зависимости от количества комнат.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null int64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23699 non-null int64
# living_area             23699 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            23699 non-null float64
# balcony                 23699 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# city_centers_nearest    18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# ### Вывод
# 1. Заменили пропущенные значения в living_area и kitchen_area
# 2. Оставленны пропуски в airports_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, так как на примере Тихвина видно, что данные могут быть просто не заполнены.
# 3. Оставлены пропуски в locality_name
# 4. Заменено название столбца cityCenters_nearest
# 5. Там где возможно поменял типы данных
# 6. Вручную избавился от дубликатов в locality_name (не от всех, от самых популярных)
# 7. Оставил пропуски в locality_name и city_centers_nearest, проведу анализ с пропущенными значениями. city_centers_nearest можно попробовать заменить по медианным для каждой группы в locality_name

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Предобработка данных выполнена, ты ничего не упустил, разобрал все пропуски.
#
# Каждая замена выполнена верно и логически обоснована.
#
# В конце шага структурированный вывод.
#
# Рекомендации по оформлению в комментарии ниже
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
#
# Рекомендация
#
# 1. Пояснения лучше писать над ячейкой, а не под. Так проект проще читать.
# 2. Не нужно перепрыгивать от одного к другому. Ты начал заполнять пропуска с площадью, потом перешел на другое, а в конце шага вернулся к пропускам с площадью
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Принял рекомендации
# </div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
#
# Рекомендация
#
# В начале шага следует написать перечень действий, который планируешь выполнить. Так ты ничего не упустишь и добавишь проекту структуры
#
# </div>

# %%
try:
    data['square_priсe'] = data['last_price'] / data['total_area']
except:
    print('Ошибка в расчетах цены квадратного метра')
data['square_priсe'] = data['square_priсe'].astype('int')

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# 👍🏻
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
#
# Рекомендация
#
# На данном шаге нужно произвести расчет и добавить результат в таблицу, графики - лишнее. Но если делаешь их, то необходимо добавить зачем.
#
# </div>

# %%
data['day'] = data['first_day_exposition'].dt.weekday
day_dict = {
    0 : 'Понедельник',
    1 : "Вторник",
    2 : "Среда",
    3 : "Четверг",
    4 : "Пятница",
    5 : "Суббота",
    6 : "Воскресенье",
}
#data['day'] = data['day'].map(day_dict) Удобней для восприятия но при построении графиков нарушается порядок

data['month'] = data['first_day_exposition'].dt.month
data['year'] = data['first_day_exposition'].dt.year
month_dict = {
    1 : "Январь",
    2 : "Февраль",
    3 : "Март",
    4 : "Апрель",
    5 : "Май",
    6 : "Июнь",
    7 : "Июль",
    8 : "Август",
    9 : "Сентябрь",
    10 : "Октябрь",
    11 : "Ноябрь",
    12 : "Декабрь",
}
#data['month'] = data['month'].map(month_dict)
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16        51.00      8         False   False
# 1             nan            11        18.60      1         False   False
# 2             nan             5        34.30      4         False   False
# 3             nan            14        45.00      9         False   False
# 4            3.03            14        32.00     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Хорошая идея со словарями, но ты прав, на графике значения будут идти не по порядку.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера
# Критично
#
# Данный график нарушает структуру проекта
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Убрал
# </div>

# %% [raw]
# for i in range(len(data)):
#     if data[i,'floor'] == 1:
#         data.loc[i,'floor_group'] = 'Первый'
#     elif data[i,'floor'] == data[i,'floors_total']:
#         data.loc[i,'floor_group'] = 'Последний'
#     data.loc[i,'floor_group'] = 'Другой'

# %% [raw]
# def floor_group(column_1, column_2):
#     if column_1 == 1:
#         return 'Первый'
#     elif column_1 == column_2:
#         return 'Последний'
#     else:
#         return 'Другой'
# data['floor_group'] = floor_group('data['floor']', 'data['floors_total']')

# %% [raw]
# def floor_group(column_1, column_2):
#     if column_1 == 1:
#         return 'Первый'
#     elif column_1 == column_2 and column_1 != 1:
#         return 'Последний'
#     else:
#         return 'Другой'
# data['floor_group'] = data[['floor','floors_total']].apply(floor_group('floor', 'floors_total'))

# %% [markdown]
# Пробовал посчитать тремя вариантами, прошу подсказать в чем ошибался.

# %%
data.loc[data['floor'] == 1, 'floor_group'] = 'Первый'
data.loc[(data['floor'] == data['floors_total']) & (data['floor'] != 1), 'floor_group'] = 'Последний'
data.loc[(data['floor'] != data['floors_total']) & (data['floor'] != 1), 'floor_group'] = 'Другой'

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
#
# 1) data[i,'floor'] == 1. Должно быть data.loc И в конце не хватает else перед data.loc[i,'floor_group'] = 'Другой'
#
# 2 и 3) По этой ссылке как применять aplly к одному столбцу и ко всему ряду
#
# https://s3.us-west-2.amazonaws.com/secure.notion-static.com/49fe703e-acfd-4f49-8bbc-113b9a04a221/___apply.pdf?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIAT73L2G45EIPT3X45%2F20211220%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20211220T192937Z&X-Amz-Expires=86400&X-Amz-Signature=f41d47fd1e8bac4a33c76abc4658d86d5fcc5381f32293f3be33766cebb5c4f4&X-Amz-SignedHeaders=host&response-content-disposition=filename%20%3D%22%25D0%259C%25D0%25B5%25D1%2582%25D0%25BE%25D0%25B4%25D0%25B8%25D1%2587%25D0%25BA%25D0%25B0_%25D0%259A%25D0%25B0%25D0%25BA%2520%25D1%2580%25D0%25B0%25D0%25B1%25D0%25BE%25D1%2582%25D0%25B0%25D0%25B5%25D1%2582%2520apply.pdf%22&x-id=GetObject
#
# </div>

# %% [markdown]
# **Разбил данные на категории по этажу**

# %%
try:
    data['living_total_ratio'] = data['living_area'] / data['total_area']
except:
    print('Ошибка в расчетах отношения жилой площади к общей')
try:
    data['kitchen_total_ratio'] = data['kitchen_area'] / data['total_area']
except:
    print('Ошибка в расчетах отношения площади кухни к общей')

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Расчеты верны 👍🏻
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# Графики надо убрать из этой части, для этого есть шаг исследователського анализа
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Убрал, сейчас уже и не вспомнить зачем я их тут делал
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 29 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null int64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23699 non-null int64
# living_area             23699 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            23699 non-null float64
# balcony                 23699 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# city_centers_nearest    18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# ### Вывод
#
# **Для дальнейшего исследования:**
# 1. Добавлена цена квадратного метра
# 2. Определены день недели, месяц, год размещения объявления
# 3. Данные классифицированы по этажу: первый, последний и другой
# 4. Посчитано отношения жилой площади к общей и площади кухни к общей

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера
# Критично
#
# Не хватает вывода по этому шагу
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Добавил вывод
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
#
# Рекомендация
#
# В начале шага следует написать перечень действий, который планируешь выполнить. Так ты ничего не упустишь и добавишь проекту структуры
#
# </div>

# %% [markdown]
# ### Анализ всех данных

# %% [raw]
# target_list = ['total_area', 'last_price', 'rooms', 'ceiling_height']
# for name in target_list:
#     data.plot(kind = 'hist', bins=100, figsize=(10,5), y=name)
#     print(data[name].describe())

# %%
data['total_area'].hist(bins=100, figsize=(10,5), range=(0,400))
data['total_area'].describe()
# Out:
# count   23699.00
# mean       60.35
# std        35.65
# min        12.00
# 25%        40.00
# 50%        52.00
# 75%        69.90
# max       900.00
# Name: total_area, dtype: float64

# %%
#plt.ylim(0,200)
data.boxplot('total_area')
len(data.query('total_area > 115'))
# Out:
# 1217

# %%
plt.ylim(0,20)
data.boxplot('total_area')
len(data.query('total_area > 115'))
# Out:
# 1217

# %%
plt.ylim(113,120)
data.boxplot('total_area')
len(data.query('total_area > 115'))
# Out:
# 1217

# %%
plt.ylim(0,200)
data.boxplot('total_area')
len(data.query('total_area > 115'))
# Out:
# 1217

# %% [markdown]
# **По диаграме размаха данные в total_area больше 114.6 метров считаются выбросами**

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# Ты ограничил боксплот значениями до 200, поэтому он и посчитал, что больше 114 это выброс. Так делать неправильно, ты некорректно интерпретируешь результаты. Данный комментарий относиться ко всем выводам на этом шаге
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Вот тут я не совсем понял, я же не фильтрую данные, а ограничевую область которую буду видеть при их визуализации, как это может влиять на данные? Ограничевал область для того что бы мне было видно какое именно значение входит в диаграмму размаха (уменьшить цену деления графика). Для примера сверху привел пару ограничений по "y", почему в них не поменялась диаграмма?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_2
#
# Тут ты прав, а я ошибся, да.
# </div>

# %%
data['last_price'].hist(bins=100, figsize=(10,5), range=(0,100000000))
data['last_price'].describe()
# Out:
# count       23699.00
# mean      6541548.77
# std      10887013.27
# min         12190.00
# 25%       3400000.00
# 50%       4650000.00
# 75%       6800000.00
# max     763000000.00
# Name: last_price, dtype: float64

# %%
plt.ylim(0,15000000)
data.boxplot('last_price')

# %% [markdown]
# **По диаграмме размаха данные со стоимость выше 11900000 считаются выбросом**

# %%
data['rooms'].hist(bins=20, figsize=(10,5))
data['rooms'].describe()
# Out:
# count   23699.00
# mean        2.07
# std         1.08
# min         0.00
# 25%         1.00
# 50%         2.00
# 75%         3.00
# max        19.00
# Name: rooms, dtype: float64

# %%
data.boxplot('rooms')

# %% [markdown]
# **Изучил данные по количеству комнат, выбросы считаются данные со значением в rooms больше 6.**

# %%
data['ceiling_height'].hist(bins=100, figsize=(10,5), range=(0,10))
data['ceiling_height'].describe()
# Out:
# count   14504.00
# mean        2.77
# std         1.26
# min         1.00
# 25%         2.52
# 50%         2.65
# 75%         2.80
# max       100.00
# Name: ceiling_height, dtype: float64

# %%
#plt.ylim(0,5)
data.boxplot('ceiling_height')

# %%
plt.ylim(0,5)
data.boxplot('ceiling_height')

# %%
plt.ylim(2,3)
data.boxplot('ceiling_height')

# %% [markdown]
# Сверху представленны данные до замены пропущенных данных в ceiling_height на медианные

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Сверху вывел еще  три раза с ограничениями. И с ограничением (2,3) вывел после замены на медианные. Наглядно видно, что ограничение визуализации на данные не влияют.
# </div>

# %%
data.loc[data['ceiling_height'].isna(), 'ceiling_height'] = data['ceiling_height'].median()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
#
# Рекомендация
#
# Это надо было сделать на шаге предобработки
#
# </div>

# %%
data['ceiling_height'].hist(bins=100, figsize=(10,5), range=(0,10))
data['ceiling_height'].describe()
# Out:
# count   23699.00
# mean        2.72
# std         0.99
# min         1.00
# 25%         2.60
# 50%         2.65
# 75%         2.70
# max       100.00
# Name: ceiling_height, dtype: float64

# %%
plt.ylim(2,3)
data.boxplot('ceiling_height')

# %% [markdown]
# сверху представлены данные после замены пропущенных значений в ceiling_height на медианные.

# %% [markdown]
# **Были проверены данные до замены и после. Если заменять пропущенные данные в ceiling_height на медианные, диаграмма размаха сильно меняет свои значения и считает за выбросы вполне реальные (на мой взгляд) данные. За выбросы буду принимать данные меньше 2.46 и выше 3.21, как было до замены**

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
#
# Рекомендация
#
# Это происходит из-за того, что ты меняешь масштаб графика
#
# </div>

# %%
data.query('days_exposition != 0')['days_exposition'].hist(bins=45, figsize=(10,5),range=(0,800))
data.query('days_exposition != 0')['days_exposition'].describe()
# Out:
# count   20518.00
# mean      180.89
# std       219.73
# min         1.00
# 25%        45.00
# 50%        95.00
# 75%       232.00
# max      1580.00
# Name: days_exposition, dtype: float64

# %%
plt.ylim(0,700)
data.query('days_exposition != 0').boxplot('days_exposition')

# %% [markdown]
# **Построена диаграмма размаха и гистаграмма по значениям в days_exposition не равным 0, так как даные объявления еще находятся в размещении. Можно поделить продажи на 4 группы:еще продается - значение 0, быстрые - от 1 дня до 45, нормальные - от 46 до 232 и долгие - от 233 до 512.**

# %% [markdown]
# **Фильтрацию буду проводить по следующим данным:**
# 1. Общая площадь меньше 400
# 1. Цена квартиры меньше 65,000,000 рублей.
# 2. Количество комнат: 6 и меньше
# 3. Высота потолков от 2,46 до 9м (такая высота может быть в домах старого фонда Санкт-Петербурга)
# 4. Завершенные объявления

# %%
data.loc[data['days_exposition'] == 0, 'sale_type'] = 'Еще продается'
data.loc[(data['days_exposition'] > 0) & (data['days_exposition'] < 46), 'sale_type'] = 'Быстро'
data.loc[(data['days_exposition'] > 45) & (data['days_exposition'] < 233), 'sale_type'] = 'Нормально'
data.loc[(data['days_exposition'] > 232) & (data['days_exposition'] < 513), 'sale_type'] = 'Долго'
data_filter_sale = data.query('days_exposition < 513 & days_exposition > 0 &ceiling_height >= 2.46 \
& ceiling_height <= 9 & rooms <= 6 & last_price < 65000000 & total_area <400')

# %%
print('После фильтрации осталось данных:' "{:.2%}".format(len(data_filter_sale)/len(data)))
# Out:
# После фильтрации осталось данных:78.81%

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# У тебя отличные, наглядные визуализации, но на этом шаге есть ряд критичных замечаний, которые надо обязательно осмыслить и исправить
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# Ни в коем случае нельзя отбрасывать данные по той причине, что боксплот считает их выбросами. Это выбросы только для боксплота, вовсе не значит, что эти данные нам не нужны для анализа. Например, ты убрал квартиры с площадью больше 114.6 кв. м. Тебе надо пересмотреть выводы и решение по чистке данных.
#
#
# После чистки стоит посчитать и проверить какую часть данных ты отбросил
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Делал ограничения по принципу которому учили, тоже сомневался в некоторых ограничениях. Изменил фильтрацию, посчитал процент оставшихся данных
# </div>

# %% [markdown]
# **Отфильтровал данные, оставил объявления которые были завершены**

# %% [markdown]
# ### Анализ данных закрытых объявлений

# %%
data_filter_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18678 entries, 1 to 23695
# Data columns (total 30 columns):
# total_images            18678 non-null int64
# last_price              18678 non-null int64
# total_area              18678 non-null float64
# first_day_exposition    18678 non-null datetime64[ns]
# rooms                   18678 non-null int64
# ceiling_height          18678 non-null float64
# floors_total            18678 non-null int64
# living_area             18678 non-null float64
# floor                   18678 non-null int64
# is_apartment            18678 non-null bool
# studio                  18678 non-null bool
# open_plan               18678 non-null bool
# kitchen_area            18678 non-null float64
# balcony                 18678 non-null float64
# locality_name           18635 non-null object
# airports_nearest        14387 non-null float64
# city_centers_nearest    14405 non-null float64
# parks_around3000        14405 non-null float64
# ...

# %%
data_filter_sale.plot(y='last_price', x='city_centers_nearest', style = 'o',alpha = 0.1,)
data_filter_sale['last_price'].corr(data_filter_sale['city_centers_nearest'])
# Out:
# -0.3120744739441867

# %% [markdown]
# **Коэфицент кореляции отрицательный, чем больше расстояние от центра тем меньше цена.**

# %%
data_filter_sale.plot(y='square_priсe', x='city_centers_nearest', style = 'o',alpha = 0.1,)
data_filter_sale['square_priсe'].corr(data_filter_sale['city_centers_nearest'])
#plt.figure(figsize=(10,10))
#plt.ylim(0,200000)
#sns.boxplot(y=data_filter_sale['square_priсe'], x=data_filter_sale['city_centers_nearest'])
# Out:
# -0.37441430957282645

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Молодец, что еще решил посчитать не только общую цену, но и цену квадратного метра
#
# </div>

# %%
data_filter_sale.plot(kind='scatter', y='last_price', x='total_area', alpha=0.1)
data_filter_sale['last_price'].corr(data_filter_sale['total_area'])
# Out:
# 0.7627284686065482

# %% [markdown]
# **Хорошо видно зависимость стоимости квартиры от ее площади**

# %%
data_filter_sale.pivot_table(index='rooms', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)
data_filter_sale['last_price'].corr(data_filter_sale['rooms'])
# Out:
# 0.4720591542714647

# %% [markdown]
# **По диаграмме и коэфиценту корреляции видно зависимость цены от количества комнат, чем больше комнат тем выше цена**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
#
# Молодец, что считаешь и среднее, и медиану
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
#
# Рекомендация
#
# Все верно, но коэффициент корреляции не выведе на экран
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Добавил вывод коэфицента корреляции
# </div>

# %%
data_filter_sale.pivot_table(index='day', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)
data_filter_sale['last_price'].corr(data_filter_sale['day'])
# Out:
# -0.00471028390635871

# %% [markdown]
# **На графике зависимости цены от дня недели особой зависимости не наблюдается, бываают спады и подъемы в пределах 1-2%**

# %%
data_filter_sale.pivot_table(index='month', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)
data_filter_sale['last_price'].corr(data_filter_sale['month'])
# Out:
# 0.004447611922066768

# %% [markdown]
# **На графике имеются небольшие колебания средней и медианной цены в диапазоне 2%. Спад стоимости в июне.**

# %%
data_filter_sale.pivot_table(index='year', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)
data_filter_sale['last_price'].corr(data_filter_sale['year'])
# Out:
# -0.04328225825905956

# %% [markdown]
# **Средняя стоимость квартир уменьшалась с 2015 до 2018 года, затем начался резкий рост, медианная стоимость начала рости на год раньше, начиная с 2017**

# %%
data_filter_sale.pivot_table(index='year', values='square_priсe', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)
data_filter_sale['square_priсe'].corr(data_filter_sale['year'])
# Out:
# 0.03473675089595629

# %% [markdown]
# **Стоимость квадратного метра медленно растет с 2015 по 2016, наблюдается небольшой спад в 2017, затем наблюдается резкий рост цены до 2019**

# %%
data_filter_sale.pivot_table(index='floor_group', values='last_price',\
                             aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# **Средняя и медианная стоимость квартир на первом этаже самая низкая, самая высокая стоимость у квартир в группе "Другой"**

# %%
data_filter_sale.corr().sort_values(by='last_price', ascending=False)['last_price']
# Out:
# last_price              1.00
# total_area              0.76
# square_priсe            0.70
# living_area             0.64
# kitchen_area            0.55
# rooms                   0.47
# ceiling_height          0.33
# ponds_around3000        0.19
# parks_around3000        0.19
# total_images            0.14
# days_exposition         0.10
# floor                   0.06
# balcony                 0.05
# floors_total            0.05
# parks_nearest           0.01
# is_apartment            0.01
# month                   0.00
# day                    -0.00
# open_plan              -0.02
# airports_nearest       -0.03
# year                   -0.04
# living_total_ratio     -0.05
# studio                 -0.05
# ponds_nearest          -0.10
# kitchen_total_ratio    -0.14
# city_centers_nearest   -0.31
# Name: last_price, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
#
# Рекомендация
#
# Корреляция - это линейная зависимость, не стоит считать ее со всем подряд. Применяй ее там, где ожидаешь увидеть линейную взаимосвязь
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Такой вывод показался мне простым и наглядным, отсортировав по убыванию сразу видно с чем связано, без перечислений.
# </div>

# %% [markdown]
# #### Вывод
#
# **По базе закрытых объявлений можно выделить следующие факторы, от которых зависит цена (0.3-0.5 слабая, 0.5-0.7 средняя, 0.7-0.9 высокая, 0.9-1 очень высокая), цену квадратного метра не учитываем, т.к. она зависит от цены и площади. Прямая зависимость цены от:**
# 1. Общей площади - средняя
# 2. Жилой площади - средняя
# 3. Площади кухни - слабая
# 4. Количества комнат - слабая
# 5. Высоты потолков - слабая
# 6. Расстояния до центра - слабая обратная.**
#
# **Цена квартир на первом и последнем этаже ниже чем цена в категории "Другой"**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Данный шаг выполнен отлично! Расчеты, визуализации и выводы верны.
#
# </div>

# %% [markdown]
# ### Топ по населеным пунктам

# %%
data_filter_sale['locality_name'].value_counts().head(10)
# Out:
# Санкт-Петербург      12350
# Мурино                 517
# Кудрово                406
# посёлок Шушары         388
# Всеволожск             308
# Колпино                292
# посёлок Парголово      286
# Пушкин                 275
# Гатчина                243
# Выборг                 191
# Name: locality_name, dtype: int64

# %%
top_localyty = data_filter_sale['locality_name'].value_counts().head(10).index
data_filter_loc = data_filter_sale.query('locality_name in @top_localyty')
data_filter_loc['locality_name'].unique()
# Out:
# array(['посёлок Шушары', 'Санкт-Петербург', 'посёлок Парголово', 'Мурино',
#        'Пушкин', 'Кудрово', 'Колпино', 'Гатчина', 'Выборг', 'Всеволожск'],
#       dtype=object)

# %%
data_filter_loc['locality_name'].value_counts().plot(kind="pie", figsize=(9,9))

# %%
data_filter_loc.pivot_table(index='locality_name', values='square_priсe').sort_values(by='square_priсe', ascending=False)
# Out:
#                    square_priсe
# locality_name
# Санкт-Петербург       109886.85
# Пушкин                101898.37
# Кудрово                94567.30
# посёлок Парголово      89367.23
# Мурино                 85947.64
# посёлок Шушары         77914.07
# Колпино                74660.64
# Всеволожск             68605.15
# Гатчина                68076.44
# Выборг                 57117.40

# %%
data_filter_loc.pivot_table(index='locality_name', values='square_priсe')\
.sort_values(by='square_priсe', ascending=False).plot(kind='bar', figsize=(9,5), grid=True)

# %% [markdown]
# #### Вывод
# **Самая высокая средняя стоимость квадратного метра в Санкт-Петербурге, самая низкая в Выборге.**

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
#
# Рекомендация
#
# Отлично, но не хватает визуализаций
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Добавил визуализации
# </div>

# %% [markdown]
# ### Анализ данных по Санкт-Петербургу

# %%
data_spb = data_filter_sale.query('locality_name == "Санкт-Петербург"')

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# Нарушена структура проекта
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Перенес в нужную часть проекта
# </div>

# %%
data_spb.pivot_table(index='rooms', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# **По диаграмме и коэфиценту корреляции видно зависимость цены от количества комнат, чем больше комнат тем выше цена**

# %%
data_spb.pivot_table(index='day', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# **На графике зависимости цены от дня недели особой зависимости не наблюдается, бываают спады и подъемы в пределах 3-5%**

# %%
data_spb.pivot_table(index='month', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# **На графике имеются небольшие колебания средней и медианной цены в диапазоне 5%. Спад средней стоимости в октбре, пик в сентябре (у медианной пик в декабре)**

# %%
data_spb.pivot_table(index='year', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# **Средняя стоимость с 2015 по 2019 растет, стояла на месте (имела незначительное понижение < 1%) в 2016-2017 годах. Медианная стоимость квартир имеет спад с 1015 по 2017, затем начался рост цены до 2019**

# %%
data_spb.pivot_table(index='year', values='square_priсe', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# **Стоимость квадратного метра стабильно растет из года в год, имеется замедление роста цены в 2016-2017 годах**

# %%
data_spb.pivot_table(index='floor_group', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# **В Санкт-Петербурге квартиры на первом этаже имееют стоимость ниже. Больше всех ценятся квартиры из категории "Другой"**

# %%
data_spb.corr().sort_values(by='last_price', ascending=False)['last_price']
# Out:
# last_price              1.00
# total_area              0.79
# square_priсe            0.68
# living_area             0.66
# kitchen_area            0.56
# rooms                   0.50
# ceiling_height          0.33
# ponds_around3000        0.21
# parks_around3000        0.20
# total_images            0.13
# days_exposition         0.13
# balcony                 0.04
# floor                   0.01
# parks_nearest           0.01
# is_apartment            0.00
# day                     0.00
# month                  -0.00
# airports_nearest       -0.01
# open_plan              -0.02
# floors_total           -0.04
# year                   -0.04
# living_total_ratio     -0.05
# studio                 -0.05
# ponds_nearest          -0.12
# kitchen_total_ratio    -0.16
# city_centers_nearest   -0.38
# Name: last_price, dtype: float64

# %% [markdown]
# #### Вывод
#
# **Стоимость квартир в Санкт-Петербурге особо не зависит от дня и месяца размещения. Наблюдается рост средней стоимости квартир в период 2015-2019 года на 5%. Квартиры на первом этаже ценятся меньше, квартиры в категории "Другой" больше.**
#
# **По коэфиценту кореляции цена на квартиры в Санкт-Петербурге зависит от:**
# 1. Общей площади - высокая
# 2. Жилой площади - средняя
# 3. Площади кухни - средняя
# 4. Количества комнат - средняя
# 5. Высота потолков - слабая
# 6. Растояние до центра - слабая обратная зависимость

# %% [markdown]
# ### Анализ данных по квартирам в центре Санкт-Петербурга

# %%
data_spb = data_spb.dropna(subset = ['city_centers_nearest'])
data_spb['km_to_centers'] = round(data_spb['city_centers_nearest'] / 1000)
data_spb['km_to_centers'] = data_spb['km_to_centers'].astype('int')
data_spb_pivot = data_spb.pivot_table(index='km_to_centers', values='last_price')
data_spb_pivot
# Out:
#                last_price
# km_to_centers
# 0             11106153.85
# 1             12377364.40
# 2             12006480.95
# 3              9361102.14
# 4             10450279.72
# 5             11408764.62
# 6             11209651.18
# 7             11092076.70
# 8              8316652.89
# 9              6599336.17
# 10             6004422.71
# 11             5739110.73
# 12             5573579.75
# 13             5887354.59
# 14             5423315.19
# 15             5514790.07
# 16             5210812.32
# 17             5037347.08
# 18             5074832.00
# 19             4906499.74
# 20             5342688.25
# 21             5120448.87
# 22             5164141.01
# 23             4586451.61
# 24             3835886.80
# 25             4052839.92
# 26             3914993.52
# 27             8300000.00
# 28             5026428.57
# 29             3833333.33

# %%
data_spb_pivot.plot(y='last_price', figsize=(10,7), grid=True)

# %% [markdown]
# **По графикам видим два резких скачка, цена сильно меняется при растоянии от центра 4км и 9км. Считаю что к центру относятся квариры с растоянием 3 и меньше км.**

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий от ревьюера v_1
# Критично
#
# Расчеты верны и визуализация наглядна (но лучше нарисовать линейный график)
#
# Но 3 км неправильно считать как центр, цена начинает резко идти вниз в районе 8 км
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Поменял фильтрацию для данных в центре.
# </div>

# %%
data_spb_center = data_spb.query('km_to_centers <=8')

# %%
data_spb_center.pivot_table(index='rooms', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
#
# Рекомендация
#
# Выглядит достаточно странно. Можно поглубже посмотреть данные и выяснить, что это за квартиры с 6-ю комнатами и почему они дешевле
#
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# После изменения радиуса центра, просадка цена на квартирах с 6-ю комнатами ушла.
# </div>

# %% [markdown]
# **По диаграмме и коэфиценту корреляции видно зависимость цены от количества комнат, чем больше комнат тем выше цена**

# %%
data_spb_center.pivot_table(index='day', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# **По медианной стоимости худшие день для размещения пятница, лучший - воскресенье.**
#
# **Амплитуда ориентировочно 10%**

# %%
data_spb_center.pivot_table(index='month', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# **На графике наблюдается пик цены в ноябре и сильный спад в декабре. Стоимость в ноябре на 15-20% больше стоимости в декабре**

# %%
data_spb_center.pivot_table(index='year', values='last_price', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# **В 2015 были самые высокие средние цены, до 2019 наблюдается снижение средней цены. Медианная имеет пик в 2016 году, потом началось снижение**

# %%
data_spb_center.pivot_table(index='year', values='square_priсe', aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# **Стоимость медианного квадратного метра стабильно растет из года в год, по средней стоимости виден небольшой спад в 2017 году**

# %%
data_spb_center.pivot_table(index='floor_group', values='last_price',\
                            aggfunc=('mean', 'median')).plot(figsize=(10,7), grid=True)

# %% [markdown]
# **В цена квартиры на последнем этаже чуть выше чем цена в группе "Другой" и значительно превышает цены квартир на первом этаже**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Графики и выводы отличные 👍🏻
#
# </div>

# %%
data_spb_center.corr().sort_values(by='last_price', ascending=False)['last_price']
# Out:
# last_price              1.00
# total_area              0.72
# square_priсe            0.70
# living_area             0.58
# kitchen_area            0.51
# rooms                   0.45
# ceiling_height          0.15
# total_images            0.15
# parks_around3000        0.14
# floor                   0.13
# days_exposition         0.13
# balcony                 0.12
# ponds_around3000        0.09
# floors_total            0.08
# airports_nearest        0.08
# is_apartment            0.00
# open_plan              -0.00
# month                  -0.00
# day                    -0.01
# parks_nearest          -0.03
# studio                 -0.05
# km_to_centers          -0.08
# city_centers_nearest   -0.08
# year                   -0.08
# ponds_nearest          -0.08
# living_total_ratio     -0.11
# kitchen_total_ratio    -0.11
# Name: last_price, dtype: float64

# %% [markdown]
# #### Вывод

# %% [markdown]
# **У квартир в центре прямая зависимость от количества комнат, чем больше комнат тем выше цена. Стоимость имеет зависимость: от дня размещения - в пятницу самая низкая цена в воскресение высокая; от месяца - в ноябре цены гараздо выше чем декабре; от года размещения - в 2016 был пик стоимости**
#
# **Зависимость стоимости цены квартиры в центре отличается от зависимости по всей базе. В центре наблюдается прямая зависимость от:**
# 1. Общей площади - высокая
# 2. Жилой площади - средняя
# 3. Количество комнат - средняя
# 4. Площадь кухни - слабая

# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий от ревьюера v_1
#
# Вывод по данному шагу 👍🏻
#
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Изучив все данные вывести общие зависимости цены:**
# 1. С каждым годом цена квадратного метра растет
# 2. Цена квартир зависит от общей площади, жилой площади, количеству комнат и расстоянию до центра.
#
# **Анализирую общие данные и данные по Санкт-Петербургу:**
# 1. Нет сильной зависимости стоимости от дня и месяца размещения.
# 2. Цена на квартиры в 2019 году имеет пик и квартиры на первом и последнем этаже ценятся меньше.**
#
# **Квартиры в центре имеют отдельные факторы влияющие на стоимость:**
# 1. От дня размещения - в пятницу самая низкая цена в воскресение высокая.
# 2. От месяца - в ноябре цены гараздо выше чем декабре
# 3. От года размещения - в 2016 был рекордный пик средней стоимости.
# 4. Квартиры на последнем этаже ценятся больше, чуть меньше в группе "Другой" и самая низкая стоимость за квартиры на первом этаже.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий от ревьюера v_1
# Рекомендация
#
# Вывод отличный и он верен, но когда он записан сплошным текстом разобрать его очень тяжело. Все выводы лучше структурировать
#
# 1.
#
# 2.
#
# 3.
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
#
# ### Комментарий студента
#
# Изменил вывод
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
